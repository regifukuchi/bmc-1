# %%
import numpy as np

# %%
time, disp, disp2, aacc = np.loadtxt('./../Asus/Desktop/UFABC/SIm&ModMH/bmc-master/data/pezzack.txt',skiprows = 6, unpack = True)

# %%
whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# aacc       ndarray    142: 142 elems, type `float64`, 1136 bytes
# disp       ndarray    142: 142 elems, type `float64`, 1136 bytes
# disp2      ndarray    142: 142 elems, type `float64`, 1136 bytes
# np         module     <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# time       ndarray    142: 142 elems, type `float64`, 1136 bytes

# %%
dp = np.mean(np.diff(time))
v = disp
for i in range(0,len(time)-1):
    v[i] = (disp[i+1]-disp[i])/dp

# %%
a = disp
for i in range(0,len(time)-1):
    a[i] = (v[i+1]-v[i])/dp

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure(figsize=(12,6))
plt.plot(time, a, label = 'computed acceleration')
plt.plot(time, aacc, label = 'true acceleration')
plt.legend()
plt.show()
